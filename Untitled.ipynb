# %%
import pandas as pd

# %%
excel_file = 'Online Retail.xlsx'

# %%
OnRet = pd.read_excel(excel_file)

# %%
OnRet.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
OnRet.shape
# Out:
# (541909, 8)

# %%
OnRet.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
OnRet['UnitPrice'].head(10).plot(kind="barh")
plt.show()

# %%
OnRet.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
null_cols = OnRet.columns[OnRet.isnull().any()]
OnRet[null_cols].isnull().sum()
# Out:
# Description      1454
# CustomerID     135080
# dtype: int64

# %%
print(OnRet[OnRet["Description"].isnull()][null_cols])
# Out:
#        Description  CustomerID
# 622            NaN         NaN
# 1970           NaN         NaN
# 1971           NaN         NaN
# 1972           NaN         NaN
# 1987           NaN         NaN
# 1988           NaN         NaN
# 2024           NaN         NaN
# 2025           NaN         NaN
# 2026           NaN         NaN
# 2406           NaN         NaN
# 4347           NaN         NaN
# 4348           NaN         NaN
# 7187           NaN         NaN
# 7188           NaN         NaN
# 7189           NaN         NaN
# 7190           NaN         NaN
# 7191           NaN         NaN
# 7192           NaN         NaN
# 7193           NaN         NaN
# 7194           NaN         NaN
# 7195           NaN         NaN
# 7196           NaN         NaN
# 7197           NaN         NaN
# 7198           NaN         NaN
# 7199           NaN         NaN
# 7200           NaN         NaN
# 7201           NaN         NaN
# 7202           NaN         NaN
# 7203           NaN         NaN
# ...

# %%
print(OnRet[OnRet.isnull().any(axis=1)][null_cols])
# Out:
#                                 Description  CustomerID
# 622                                     NaN         NaN
# 1443        DECORATIVE ROSE BATHROOM BOTTLE         NaN
# 1444        DECORATIVE CATS BATHROOM BOTTLE         NaN
# 1445                     POLKADOT RAIN HAT          NaN
# 1446                  RAIN PONCHO RETROSPOT         NaN
# 1447                     VINTAGE SNAP CARDS         NaN
# 1448     VINTAGE HEADS AND TAILS CARD GAME          NaN
# 1449    CHRISTMAS TREE DECORATION WITH BELL         NaN
# 1450        CHRISTMAS TREE HEART DECORATION         NaN
# 1451         CHRISTMAS TREE STAR DECORATION         NaN
# 1452       CHRISTMAS HANGING TREE WITH BELL         NaN
# 1453       CHRISTMAS HANGING STAR WITH BELL         NaN
# 1454      CHRISTMAS HANGING HEART WITH BELL         NaN
# 1455       GLITTER STAR GARLAND WITH BELLS          NaN
# 1456      GLITTER CHRISTMAS TREE WITH BELLS         NaN
# 1457    PAINTED METAL HEART WITH HOLLY BELL         NaN
# ...

# %%
OnRet.iloc[[622]]
# Out:
#     InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622    536414     22139         NaN        56 2010-12-01 11:52:00        0.0
#
#      CustomerID         Country
# 622         NaN  United Kingdom

# %%
OnRet.iloc[[2026]]
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 2026    536554     84670         NaN        23 2010-12-01 14:35:00        0.0
#
#       CustomerID         Country
# 2026         NaN  United Kingdom

# %%
OnRet['CustomerID'].value_counts()
# Out:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
# 15311.0    2491
# 14646.0    2085
# 13089.0    1857
# 13263.0    1677
# 14298.0    1640
# 15039.0    1508
# 14156.0    1420
# 18118.0    1284
# 14159.0    1212
# 14796.0    1165
# 15005.0    1160
# 16033.0    1152
# 14056.0    1128
# 14769.0    1094
# 17511.0    1076
# 13081.0    1061
# 14527.0    1011
# 16549.0     981
# 14456.0     977
# 15719.0     938
# 15555.0     925
# 16931.0     898
# 17811.0     872
# 14505.0     803
# 12415.0     778
#            ...
# 15590.0       1
# 16078.0       1
# 16093.0       1
# 13703.0       1
# 18068.0       1
# 14705.0       1
# 16138.0       1
# 16144.0       1
# 16148.0       1
# 15562.0       1
# 15524.0       1
# 12503.0       1
# 12505.0       1
# 15510.0       1
# 15316.0       1
# 17956.0       1
# 17948.0       1
# 16323.0       1
# 14090.0       1
# 17925.0       1
# 17923.0       1
# 16428.0       1
# 14119.0       1
# 15389.0       1
# ...

# %%
OnRet.iloc[[654]]
# Out:
#     InvoiceNo StockCode                   Description  Quantity  \
# 654    536415     22941  CHRISTMAS LIGHTS 10 REINDEER         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 654 2010-12-01 11:57:00        8.5     12838.0  United Kingdom

# %%
OnRet['CustomerID'].value_counts().values.tolist()
# Out:
# [7983,
#  5903,
#  5128,
#  4642,
#  2782,
#  2491,
#  2085,
#  1857,
#  1677,
#  1640,
#  1508,
#  1420,
#  1284,
#  1212,
#  1165,
#  1160,
#  1152,
#  1128,
#  1094,
#  1076,
#  1061,
#  1011,
#  981,
#  977,
#  938,
#  925,
#  898,
#  872,
#  803,
#  778,
#  757,
#  756,
#  742,
#  741,
#  721,
#  720,
#  718,
#  710,
#  705,
#  702,
#  696,
#  696,
#  690,
#  674,
#  671,
#  668,
#  662,
#  653,
#  646,
#  633,
#  632,
#  631,
#  612,
#  612,
#  605,
#  604,
#  590,
#  588,
#  585,
#  582,
#  576,
#  566,
#  565,
#  563,
#  561,
#  560,
#  558,
#  551,
#  548,
#  547,
#  547,
#  546,
#  533,
#  531,
#  525,
#  523,
#  519,
#  516,
#  513,
#  509,
#  506,
#  505,
#  503,
#  502,
#  501,
#  501,
#  501,
#  500,
#  495,
#  489,
#  487,
#  487,
#  481,
#  479,
#  474,
#  474,
#  474,
#  472,
#  472,
#  470,
#  468,
#  463,
#  463,
#  461,
#  459,
#  457,
#  454,
#  452,
#  452,
#  451,
#  451,
#  449,
#  447,
#  447,
#  446,
#  444,
#  439,
#  439,
#  437,
#  436,
#  433,
#  429,
# ...

# %%
OnRet['CustomerID'].value_counts().index.tolist()
# Out:
# [17841.0,
#  14911.0,
#  14096.0,
#  12748.0,
#  14606.0,
#  15311.0,
#  14646.0,
#  13089.0,
#  13263.0,
#  14298.0,
#  15039.0,
#  14156.0,
#  18118.0,
#  14159.0,
#  14796.0,
#  15005.0,
#  16033.0,
#  14056.0,
#  14769.0,
#  17511.0,
#  13081.0,
#  14527.0,
#  16549.0,
#  14456.0,
#  15719.0,
#  15555.0,
#  16931.0,
#  17811.0,
#  14505.0,
#  12415.0,
#  17338.0,
#  18283.0,
#  17757.0,
#  12921.0,
#  17675.0,
#  15159.0,
#  16764.0,
#  16904.0,
#  13137.0,
#  15547.0,
#  16923.0,
#  17920.0,
#  17735.0,
#  15529.0,
#  16360.0,
#  16729.0,
#  16241.0,
#  15856.0,
#  12681.0,
#  13969.0,
#  16713.0,
#  14502.0,
#  14415.0,
#  13230.0,
#  13098.0,
#  14194.0,
#  14088.0,
#  16686.0,
#  13694.0,
#  17611.0,
#  14667.0,
#  17238.0,
#  17602.0,
#  15023.0,
#  15358.0,
#  15993.0,
#  14534.0,
#  12867.0,
#  17337.0,
#  15861.0,
#  16910.0,
#  17231.0,
#  14367.0,
#  12471.0,
#  12682.0,
#  15498.0,
#  15356.0,
#  17059.0,
#  15033.0,
#  15998.0,
#  14895.0,
#  14049.0,
#  17346.0,
# ...

# %%
OnRet.iloc[[17841]]
# Out:
#       InvoiceNo StockCode                      Description  Quantity  \
# 17841    537781     22086  PAPER CHAIN KIT 50'S CHRISTMAS          1
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 17841 2010-12-08 12:46:00       2.95     17341.0  United Kingdom

# %%
df = OnRet.groupby('CustomerID')['CustomerID'].nunique()

# %%
df.head()
# Out:
# CustomerID
# 12346.0    1
# 12347.0    1
# 12348.0    1
# 12349.0    1
# 12350.0    1
# Name: CustomerID, dtype: int64

# %%
df
# Out:
# CustomerID
# 12346.0    1
# 12347.0    1
# 12348.0    1
# 12349.0    1
# 12350.0    1
# 12352.0    1
# 12353.0    1
# 12354.0    1
# 12355.0    1
# 12356.0    1
# 12357.0    1
# 12358.0    1
# 12359.0    1
# 12360.0    1
# 12361.0    1
# 12362.0    1
# 12363.0    1
# 12364.0    1
# 12365.0    1
# 12367.0    1
# 12370.0    1
# 12371.0    1
# 12372.0    1
# 12373.0    1
# 12374.0    1
# 12375.0    1
# 12377.0    1
# 12378.0    1
# 12379.0    1
# 12380.0    1
#           ..
# 18245.0    1
# 18246.0    1
# 18248.0    1
# 18249.0    1
# 18250.0    1
# 18251.0    1
# 18252.0    1
# 18255.0    1
# 18256.0    1
# 18257.0    1
# 18259.0    1
# 18260.0    1
# 18261.0    1
# 18262.0    1
# 18263.0    1
# 18265.0    1
# 18268.0    1
# 18269.0    1
# 18270.0    1
# 18272.0    1
# 18273.0    1
# 18274.0    1
# 18276.0    1
# 18277.0    1
# 18278.0    1
# 18280.0    1
# 18281.0    1
# 18282.0    1
# 18283.0    1
# 18287.0    1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
OnRet['CustomerID'].nunique()
# Out:
# 4372

# %%
OnRet['CustomerID']
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
# 5         17850.0
# 6         17850.0
# 7         17850.0
# 8         17850.0
# 9         13047.0
# 10        13047.0
# 11        13047.0
# 12        13047.0
# 13        13047.0
# 14        13047.0
# 15        13047.0
# 16        13047.0
# 17        13047.0
# 18        13047.0
# 19        13047.0
# 20        13047.0
# 21        13047.0
# 22        13047.0
# 23        13047.0
# 24        13047.0
# 25        13047.0
# 26        12583.0
# 27        12583.0
# 28        12583.0
# 29        12583.0
#            ...
# 541879    15804.0
# 541880    15804.0
# 541881    15804.0
# 541882    15804.0
# 541883    15804.0
# 541884    15804.0
# 541885    15804.0
# 541886    15804.0
# 541887    15804.0
# 541888    15804.0
# 541889    15804.0
# 541890    13113.0
# 541891    13113.0
# 541892    13113.0
# 541893    13113.0
# 541894    12680.0
# 541895    12680.0
# 541896    12680.0
# 541897    12680.0
# ...
